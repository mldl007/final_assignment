# %%
import tensorflow as tf
import os
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# %%
def load_data():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
    np.random.seed(42)
    tf.random.set_seed(42)
    shuffle_idx = np.arange(len(x_train))
    np.random.shuffle(shuffle_idx)
    x_train = x_train[shuffle_idx]
    y_train = y_train[shuffle_idx]

    x_train = x_train.reshape(len(x_train), 28, 28, 1)
    x_test = x_test.reshape(len(x_test), 28, 28, 1)
    return x_train, x_test, y_train, y_test

# %%
def prepare_data(x_train, x_test, y_train, y_test):
    train_datagen = ImageDataGenerator(height_shift_range=0.1,
                                       width_shift_range=0.25,
                                       rotation_range=30,
                                       zoom_range=0.2,
                                       rescale=1. / 255,
                                       fill_mode='nearest')
    test_datagen = ImageDataGenerator(rescale=1. / 255)
    
    training_data = train_datagen.flow(x_train, y_train, batch_size=32, seed=42)
    validation_data = test_datagen.flow(x_test, y_test, batch_size=32, seed=42, shuffle=False)
    return training_data, validation_data

# %%
def build_model_1():
    tf.random.set_seed(11)
    cnn = tf.keras.models.Sequential()
    cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu',
                                   input_shape=(28, 28, 1),
                                   padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu', padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Conv2D(filters=8, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu', padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Flatten())
    # cnn.add(tf.keras.layers.Dense(128, activation="relu"))
    # cnn.add(tf.keras.layers.Dropout(0.2))
    cnn.add(tf.keras.layers.Dense(16, activation="relu"))
    cnn.add(tf.keras.layers.Dropout(0.2))
    cnn.add(tf.keras.layers.Dense(10, activation="softmax"))
    return cnn

# %%
build_model_1().summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        4624
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 8)           1160
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 8)          0
#  2D)
#
#  flatten (Flatten)           (None, 72)                0
#
#  dense (Dense)               (None, 16)                1168
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 7,442
# Trainable params: 7,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
def build_model_2():
    tf.random.set_seed(11)
    cnn = tf.keras.models.Sequential()
    cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu',
                                   input_shape=(28, 28, 1),
                                   padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Conv2D(filters=16, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu', padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Conv2D(filters=8, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu', padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Flatten())
    cnn.add(tf.keras.layers.Dense(20, activation="relu"))
    cnn.add(tf.keras.layers.Dropout(0.2))
    cnn.add(tf.keras.layers.Dense(10, activation="softmax"))
    return cnn

# %%
build_model_2().summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 16)        4624
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 8)           1160
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 8)          0
#  2D)
#
#  flatten_1 (Flatten)         (None, 72)                0
#
#  dense_2 (Dense)             (None, 20)                1460
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 7,774
# Trainable params: 7,774
# Non-trainable params: 0
# _________________________________________________________________

# %%
def build_model_3():
    tf.random.set_seed(11)
    cnn = tf.keras.models.Sequential()
    cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu',
                                   input_shape=(28, 28, 1),
                                   padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Conv2D(filters=15, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu', padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Conv2D(filters=10, kernel_size=3, strides=1,
                                   data_format='channels_last',
                                   activation='relu', padding="same"))
    cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    cnn.add(tf.keras.layers.Flatten())
    cnn.add(tf.keras.layers.Dense(18, activation="relu"))
    cnn.add(tf.keras.layers.Dropout(0.2))
    cnn.add(tf.keras.layers.Dense(10, activation="softmax"))
    return cnn

# %%
build_model_3().summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 15)        4335
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 15)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 10)          1360
#
#  max_pooling2d_8 (MaxPooling  (None, 3, 3, 10)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 90)                0
#
#  dense_4 (Dense)             (None, 18)                1638
#
#  dropout_2 (Dropout)         (None, 18)                0
#
#  dense_5 (Dense)             (None, 10)                190
#
# =================================================================
# Total params: 7,843
# Trainable params: 7,843
# Non-trainable params: 0
# _________________________________________________________________

# %%
def train_model(model_name: str="model1"):
    x_train, x_test, y_train, y_test = load_data()
    training_data, validation_data = prepare_data(x_train, x_test, y_train, y_test)
    if model_name == "model1":
        cnn = build_model_1()
    elif model_name == "model2":
        cnn = build_model_2()
    else:
        cnn = build_model_3()
    cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
            metrics="sparse_categorical_accuracy")
    early_stop = EarlyStopping(monitor='val_loss', patience=3)
    history = cnn.fit(training_data, epochs=15, callbacks=[early_stop],
                  validation_data=validation_data)
    test_score = cnn.evaluate(validation_data)[1]
    return cnn, history, test_score

# %%
model_1, history_1, test_score_1 = train_model("model1")
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 36s 18ms/step - loss: 1.3770 - sparse_categorical_accuracy: 0.5068 - val_loss: 0.3376 - val_sparse_categorical_accuracy: 0.9192
# Epoch 2/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.9387 - sparse_categorical_accuracy: 0.6777 - val_loss: 0.2396 - val_sparse_categorical_accuracy: 0.9376
# Epoch 3/15
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.7814 - sparse_categorical_accuracy: 0.7378 - val_loss: 0.1851 - val_sparse_categorical_accuracy: 0.9494
# Epoch 4/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.6721 - sparse_categorical_accuracy: 0.7789 - val_loss: 0.1625 - val_sparse_categorical_accuracy: 0.9557
# Epoch 5/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.6060 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.1611 - val_sparse_categorical_accuracy: 0.9521
# Epoch 6/15
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.5509 - sparse_categorical_accuracy: 0.8222 - val_loss: 0.1334 - val_sparse_categorical_accuracy: 0.9601
# Epoch 7/15
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.5106 - sparse_categorical_accuracy: 0.8358 - val_loss: 0.1193 - val_sparse_categorical_accuracy: 0.9639
# Epoch 8/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.4673 - sparse_categorical_accuracy: 0.8503 - val_loss: 0.1318 - val_sparse_categorical_accuracy: 0.9612
# Epoch 9/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.4362 - sparse_categorical_accuracy: 0.8608 - val_loss: 0.1270 - val_sparse_categorical_accuracy: 0.9616
# Epoch 10/15
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.4234 - sparse_categorical_accuracy: 0.8670 - val_loss: 0.1042 - val_sparse_categorical_accuracy: 0.9692
# Epoch 11/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.3981 - sparse_categorical_accuracy: 0.8758 - val_loss: 0.1049 - val_sparse_categorical_accuracy: 0.9698
# Epoch 12/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.3858 - sparse_categorical_accuracy: 0.8795 - val_loss: 0.1171 - val_sparse_categorical_accuracy: 0.9654
# Epoch 13/15
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.3746 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.1076 - val_sparse_categorical_accuracy: 0.9706
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1076 - sparse_categorical_accuracy: 0.9706

# %%
model_2, history_2, test_score_2 = train_model("model2")
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 37s 18ms/step - loss: 1.1540 - sparse_categorical_accuracy: 0.5985 - val_loss: 0.2395 - val_sparse_categorical_accuracy: 0.9324
# Epoch 2/15
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.6651 - sparse_categorical_accuracy: 0.7792 - val_loss: 0.1581 - val_sparse_categorical_accuracy: 0.9518
# Epoch 3/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.5227 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.1288 - val_sparse_categorical_accuracy: 0.9621
# Epoch 4/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.4614 - sparse_categorical_accuracy: 0.8517 - val_loss: 0.1146 - val_sparse_categorical_accuracy: 0.9655
# Epoch 5/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.4050 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.1036 - val_sparse_categorical_accuracy: 0.9671
# Epoch 6/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.3793 - sparse_categorical_accuracy: 0.8801 - val_loss: 0.0900 - val_sparse_categorical_accuracy: 0.9721
# Epoch 7/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.3515 - sparse_categorical_accuracy: 0.8899 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9695
# Epoch 8/15
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.3327 - sparse_categorical_accuracy: 0.8963 - val_loss: 0.0885 - val_sparse_categorical_accuracy: 0.9732
# Epoch 9/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.3139 - sparse_categorical_accuracy: 0.9021 - val_loss: 0.0814 - val_sparse_categorical_accuracy: 0.9761
# Epoch 10/15
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.3040 - sparse_categorical_accuracy: 0.9060 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9753
# Epoch 11/15
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.2886 - sparse_categorical_accuracy: 0.9092 - val_loss: 0.0722 - val_sparse_categorical_accuracy: 0.9786
# Epoch 12/15
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2758 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.0736 - val_sparse_categorical_accuracy: 0.9776
# Epoch 13/15
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.2668 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.0801 - val_sparse_categorical_accuracy: 0.9753
# Epoch 14/15
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2632 - sparse_categorical_accuracy: 0.9189 - val_loss: 0.0800 - val_sparse_categorical_accuracy: 0.9784
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0800 - sparse_categorical_accuracy: 0.9784

# %%
model_3, history_3, test_score_3 = train_model("model3")
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 34s 17ms/step - loss: 1.1884 - sparse_categorical_accuracy: 0.5907 - val_loss: 0.2364 - val_sparse_categorical_accuracy: 0.9357
# Epoch 2/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.6688 - sparse_categorical_accuracy: 0.7806 - val_loss: 0.1687 - val_sparse_categorical_accuracy: 0.9474
# Epoch 3/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.5491 - sparse_categorical_accuracy: 0.8229 - val_loss: 0.1122 - val_sparse_categorical_accuracy: 0.9628
# Epoch 4/15
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.4718 - sparse_categorical_accuracy: 0.8502 - val_loss: 0.1032 - val_sparse_categorical_accuracy: 0.9652
# Epoch 5/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.4337 - sparse_categorical_accuracy: 0.8621 - val_loss: 0.1149 - val_sparse_categorical_accuracy: 0.9632
# Epoch 6/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.4001 - sparse_categorical_accuracy: 0.8745 - val_loss: 0.1237 - val_sparse_categorical_accuracy: 0.9603
# Epoch 7/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.3748 - sparse_categorical_accuracy: 0.8835 - val_loss: 0.0945 - val_sparse_categorical_accuracy: 0.9688
# Epoch 8/15
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.3491 - sparse_categorical_accuracy: 0.8915 - val_loss: 0.1072 - val_sparse_categorical_accuracy: 0.9656
# Epoch 9/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.3297 - sparse_categorical_accuracy: 0.8986 - val_loss: 0.0958 - val_sparse_categorical_accuracy: 0.9703
# Epoch 10/15
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.3298 - sparse_categorical_accuracy: 0.8991 - val_loss: 0.0945 - val_sparse_categorical_accuracy: 0.9713
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9713

# %%
def get_model_params_count(model):
  trainableParams = np.sum([np.prod(v.get_shape()) for v in model.trainable_weights])
  nonTrainableParams = np.sum([np.prod(v.get_shape()) for v in model.non_trainable_weights])
  totalParams = trainableParams + nonTrainableParams
  return totalParams

# %%
comparison = pd.DataFrame({'model': ['model_1', 'model_2', 'model_3'], 'accuracy': [test_score_1, test_score_2, test_score_3],
                           'Params': [get_model_params_count(model_1), get_model_params_count(model_2), get_model_params_count(model_3)]})

# %%
comparison
# Out:
#      model  accuracy  Params
# 0  model_1    0.9706  7442.0
# 1  model_2    0.9784  7774.0
# 2  model_3    0.9713  7843.0
